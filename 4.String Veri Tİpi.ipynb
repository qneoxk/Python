# %% [markdown]
# <span style = "color : red; font-size: 32px;"> string (metin - txt) veri tipi </span>

# %%
x1 = 'Mustafa Kemal' #tek tırnak ile string tanımalama
x1
# Out:
# 'Mustafa Kemal'

# %%
x2 = "Mustafa Kemal" # çift tırnak ile string tanımlama
x2
# Out:
# 'Mustafa Kemal'

# %%
x3 = """Mustafa Kemal""" # üç tane çift tırnak ile string tanımlama 
x3
# Out:
# 'Mustafa Kemal'

# %%
type(x1)
# Out:
# str

# %%
print(type(x1))
# Out:
# <class 'str'>

# %%
print(x1)
print(x2)
print(x3)
# Out:
# Mustafa Kemal
# Mustafa Kemal
# Mustafa Kemal

# %%
'Kağan'ın bugün dersi var  # tek tırnak ve kesme işareti sorunsalı
# Out:
#   Cell In[7], line 1
#     'Kağan'ın bugün dersi var  # tek tırnak ve kesme işareti sorunsalı
#            ^
# SyntaxError: invalid syntax

# %%
"Kağan'ın bugün dersi var" # sorunsalı çift tırnak ile aşmak
# Out:
# "Kağan'ın bugün dersi var"

# %%
'Kağan\'ın bugün dersi var' # \ (ters slaş ile sorunlası aşmak)
# Out:
# "Kağan'ın bugün dersi var"

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> stringler üzerine işlemler </span>

# %%
a = "Fener"
b = "Bahçe"

# %%
print(a)
print(b)
print(a, b)
# Out:
# Fener
# Bahçe
# Fener Bahçe

# %%
c = a + b 
c
# Out:
# 'FenerBahçe'

# %%
c * 5
# Out:
# 'FenerBahçeFenerBahçeFenerBahçeFenerBahçeFenerBahçe'

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> print() string metotları </span>

# %% [markdown]
# > <span style="font-size: 16px; color: skyblue; ">
# > 📌 upper(): String nesnesindeki tüm karakterleri büyük harfe döndürür.<br>
# > ☀️ lower(): String nesnesindeki tüm karakterleri küçük harfe döndürür. <br>
# > 🧬 capitalize(): String nesnesindeki ilk karakteri büyük harfe, geri kalanını küçük harfe döndürür. <br>
# > ✨ title(): String nesnesindeki her kelimenin ilk harfini büyük harfe döndürür. <br>
# > ❌ index(sub): String nesnesinde sub parametresiyle belirtilen alt karakter dizisinin ilk bulunduğu indeksi döndürür. Eğer bulamazsa ValueError hatası verir. <br>
# > 🐍 join(iterable): Iterable parametresiyle belirtilen bir dizi veya liste gibi yinelenebilir bir veri tipinin elemanlarını string nesnesiyle birleştirerek yeni bir string nesnesi döndürür.<br>
# > 🦋 replace(old, new): String nesnesindeki old parametresiyle belirtilen karakterleri new parametresiyle belirtilen karakterlerle değiştirir.<br>
# > 🎉 find(sub): String nesnesinde sub parametresiyle belirtilen alt karakter dizisinin ilk bulunduğu indeksi döndürür. Eğer bulamazsa -1 döndürür.
# > </span>

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> upper() </span>

# %%
x = "harun sinanoğlu"

# %%
x.upper()
# Out:
# 'HARUN SINANOĞLU'

# %%
x
# Out:
# 'harun sinanoğlu'

# %%
y = x.upper()
y
# Out:
# 'HARUN SINANOĞLU'

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> lower() </span>

# %%
z = y.lower()
z
# Out:
# 'harun sinanoğlu'

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> capitalize() </span>

# %%
x.capitalize()
# Out:
# 'Harun sinanoğlu'

# %%
u = "vatanını en çok seven görevini en iyi yapandır."
u
# Out:
# 'vatanını en çok seven görevini en iyi yapandır.'

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> title() </span>

# %%
u.title()
# Out:
# 'Vatanını En Çok Seven Görevini En Iyi Yapandır.'

# %%
x.title()
# Out:
# 'Harun Sinanoğlu'

# %%
x
# Out:
# 'harun sinanoğlu'

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> index() </span>

# %%
x.index("a")
# Out:
# 1

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> join() </span>

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> join() - stringlerle </span>

# %%
x
# Out:
# 'harun sinanoğlu'

# %%
x.title().join("//")
# Out:
# '/Harun Sinanoğlu/'

# %%
x.title().join("+ +")
# Out:
# '+Harun Sinanoğlu Harun Sinanoğlu+'

# %%
x.title().join("+  +")
# Out:
# '+Harun Sinanoğlu Harun Sinanoğlu Harun Sinanoğlu+'

# %% [markdown]
# <span style = "color : red; font-size: 32px;"> join() - farklı bir özellik </span>

# %% [markdown]
# <span style = "color : skyblue; font-size: 16px;"> join(): Listenin elemanlarını bir string değeri ile değiştirmeye yarar.  </span>

# %%
liste = ["19", "Mayıs", "1919"]
liste
# Out:
# ['19', 'Mayıs', '1919']

# %%
"/".join(liste) # listenin her bir elemanına / yerleştirir
# Out:
# '19/Mayıs/1919'

# %%
liste2 = ["T", "B", "M", "M"]
liste2
# Out:
# ['T', 'B', 'M', 'M']

# %%
".".join(liste2)
# Out:
# 'T.B.M.M'

# %% [markdown]
# <span style = "color : red; font-size: 28px;"> replace()  </span>

# %%
"Kimler geldi kimler geçti".replace("e", "xxxxxx")
# Out:
# 'Kimlxxxxxxr gxxxxxxldi kimlxxxxxxr gxxxxxxçti'

# %%
"Kimler geldi kimler geçti".replace(" ", "**")
# Out:
# 'Kimler**geldi**kimler**geçti'

# %% [markdown]
# <span style = "color : red; font-size: 28px;"> startswith() ve endswith() </span>

# %% [markdown]
# > <span style="font-size: 16px; color: skyblue; ">
# > 📌 startwith(x) : String x ile başlıyorsa True döner, aksi halde False.<br>
# > ❌  endswith() : String x ile bitiyorsa True döner, aksi halde False. <br>
# > </span>

# %%
"Python".startswith("p")
# Out:
# False

# %%
"Python".startswith("P")
# Out:
# True

# %% [markdown]
# <span style = "color : red; font-size: 28px;"> split()  </span>

# %% [raw]
# split(a) : Verilen değere göre string parçalara ayrılarak herbir parça listeye atılır.

# %%
liste = "Python Programlama Dili".split(" ")
liste
# Out:
# ['Python', 'Programlama', 'Dili']

# %%
liste2 = "Python Programlama Dili".split("y")
liste2
# Out:
# ['P', 'thon Programlama Dili']

# %%
liste3 = "Python-Javascript-C++-Java-C#".split("-")
liste3
# Out:
# ['Python', 'Javascript', 'C++', 'Java', 'C#']

# %% [markdown]
# <span style = "color : red; font-size: 28px;"> strip(), lstrip() ve rstrip()  </span>

# %% [markdown]
# > <span style="font-size: 16px; color: skyblue; ">
# > 📌 strip(x): Stringin başında ve sonunda bulunan x değerlerini siler. <br>
# > ❌ lstrip(x): Stringin sadece başında bulunan x değerlerini siler. <br>
# > ✅ rstrip(): Stringin sadece sonunda bulunan x değerlerini siler.
# > </span>

# %%
"      python         ".strip()
# Out:
# 'python'

# %%
"******python*****************".strip("*")
# Out:
# 'python'

# %%
"******python*****************".lstrip("*")
# Out:
# 'python*****************'

# %%
"******python*****************".rstrip("*")
# Out:
# '******python'

# %% [markdown]
# <span style = "color : red; font-size: 28px;"> count()  </span>

# %% [markdown]
# > <span style="font-size: 16px; color: skyblue; ">
# > 📌 count(x) : String içinde kaç tane x var <br>
# > ❌ count(x, index): String içindeki x'leri verilen index değerinden başlayarak sayar. <br>
# > </span>

# %%
"Hayalet Akbaba".count("a")
# Out:
# 4

# %%
"Hayalet Akbaba".count(" ")
# Out:
# 1

# %%
"Hayalet Akbaba".count("a", 4)
# Out:
# 2

# %% [markdown]
# <span style = "color : red; font-size: 28px;"> find() ve rfind()  </span>

# %% [markdown]
# > <span style="font-size: 16px; color: skyblue; ">
# > 📌 find(x) : x değerini baştan sona tarar ve bulduğu ilk indeksi yazar. Bulamazsa "-1" döner. <br>
# > ❌ rfind() : x değerini sondan başa tarar ve ilk bulduğu indeksi yazar. Bulamazsa "-1" döner. <br>
# > </span>

# %%
"araba".find("a")
# Out:
# 0

# %%
"araba".rfind("a")
# Out:
# 4

# %%
"araba".find("e")
# Out:
# -1

# %% [markdown]
# <span style = "color : red; font-size: 28px;"> String indeksleme ve parçalama  </span>

# %% [markdown]
# > <span style="font-size: 16px; color: skyblue; ">
# > 📌 Python'daki tüm veri tipleri indekslidir ve diğer veri tipleri için aynı kurallar geçerlidir. <br>
# > ❌ soldan sağa doğru sıfırdan başlayarak artan sırayla indisleme yapılır. <br>
# > </span>

# %%
u = "Disk "
u
# Out:
# 'Disk '

# %%
u[2]
# Out:
# 's'

# %%
u[4]
# Out:
# ' '

# %% [markdown]
# > <span style="font-size: 16px; color: skyblue; ">
# > 📌 sağdan sola doğru -1' den başlayarak azalan sırada sayım ypaılır. <br>
# > </span>

# %%
u[-1]
# Out:
# ' '

# %%
u[-2]
# Out:
# 'k'

# %%
Q = "Çiğdem Talu & Melih Kibar "
Q
# Out:
# 'Çiğdem Talu & Melih Kibar '

# %%
len(Q)
# Out:
# 26

# %%
Q[0:3]
# Out:
# 'Çiğ'

# %%
Q[:3]
# Out:
# 'Çiğ'

# %%
Q[7:14]
# Out:
# 'Talu & '

# %%
len(Q)
# Out:
# 26

# %%
Q
# Out:
# 'Çiğdem Talu & Melih Kibar '

# %%
Q[0:26:3]
# Out:
# 'Çd l&ehir'

# %%
Q[::3]
# Out:
# 'Çd l&ehir'

# %%
Q[::-1]
# Out:
# ' rabiK hileM & ulaT medğiÇ'

# %%
S = "Mertaba"
S
# Out:
# 'Mertaba'

# %%
S[3] = "h"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 S[3] = "h"
#
# TypeError: 'str' object does not support item assignment

# %%
ss = S.replace("t", "h")
ss
# Out:
# 'Merhaba'
